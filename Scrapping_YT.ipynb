# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
def video_comments(video_id):

	# buat list untuk menampung komentar youtube
	replies = []

	# buat object dg nama youtube untuk terhubung dengan youtube.com melalui api v3
	youtube = build('youtube', 'v3', developerKey=api_key)

	# buat variabel video respone untuk menampung object komen dari video yang diiginkan (video_id)
	video_response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id).execute()

	# lakukan perulangan untuk memasukan komentar kedalam list replies
	while video_response:

		for item in video_response['items']:

			# Esktrak komentar
			published = item['snippet']['topLevelComment']['snippet']['publishedAt']
			user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']

			# Esktrak komentar
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']

			#menambah komentar kedalam list replies
			replies.append([published, user, comment, likeCount])

			# menghitung jumlah balasan dari sebuah komentar
			replycount = item['snippet']['totalReplyCount']

			# melakuka ektrak komentar dari balasan komentar jika ada
			if replycount>0:
				# perulangan untuk mendapatkan komentar balasan
				for reply in item['replies']['comments']:

					# ekstrak text balasan komentar
					published = reply['snippet']['publishedAt']
					user = reply['snippet']['authorDisplayName']
					repl = reply['snippet']['textDisplay']
					likeCount = reply['snippet']['likeCount']

					##menambah balasan komentar  kedalam list replies
					replies.append([published, user, repl, likeCount])

		# ulangi unntuk halaman berikutnya
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					pageToken = video_response['nextPageToken'],
					videoId = video_id
				).execute()
		else:
			break
	#endwhile
	return replies

# %%
api_key = 'AIzaSyB1FIM008Ziq0dDf4knCo9mUvGGxuMwRqE'

# Enter video id
# contoh url video = https://www.youtube.com/watch?v=s4B-EBsXcH8&ab_channel=CURHATBANGDennySumargo
video_id = "s4B-EBsXcH8" #isikan dengan kode / ID video

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2024-07-11T14:40:58Z',
#   '@Mia-Khoirunnisa',
#   'Yaa Allah semoga anak2ku bisa seperti mereka 🤲😇<br>COC ini acara yang sangat disukai anakku.<br>IP mereka gak kaleng2... Semua mendekati IP 4 😮<br><br>SEMPURNAAAA..... 😍',
#   0],
#  ['2024-07-11T14:39:54Z',
#   '@indryiswary3478',
#   'Barakallahu fii Ilmi anak² cerdas. Semoga kecerdasan &amp; vibes² positif&#39;a bisa menular.❤',
#   0],
#  ['2024-07-11T14:39:45Z', '@ahmadhelmy8978', '🔥🔥🔥🔥', 0],
#  ['2024-07-11T14:39:35Z',
#   '@mutiahalendra445',
#   'Suka bamget ngulang&quot;, durasinya 1 jam, aku nontonnya hampir 2 jam😢❤',
#   0],
#  ['2024-07-11T14:39:32Z',
#   '@nuzulultazkiya627',
#   '&quot;Setiap proses pasti selalu ada orang yang mungkin tidak sesuai dengan ekspektasi kita&quot;',
#   0],
#  ['2024-07-11T14:39:21Z', '@ahmadhelmy8978', '🔥🔥🔥🔥🔥', 1],
#  ['2024-07-11T14:39:21Z',
#   '@fiiamanillah1816',
#   'Enak banget di circle mereka❤',
#   0],
#  ['2024-07-11T14:36:43Z',
#   '@faris_sandreas',
# ...

# %%
df = pd.DataFrame(comments, columns=['publishedAt', 'authorDisplayName', 'textDisplay', 'likeCount'])
df
# Out:
#                publishedAt          authorDisplayName  \
# 0     2024-07-11T14:40:58Z           @Mia-Khoirunnisa
# 1     2024-07-11T14:39:54Z           @indryiswary3478
# 2     2024-07-11T14:39:45Z            @ahmadhelmy8978
# 3     2024-07-11T14:39:35Z          @mutiahalendra445
# 4     2024-07-11T14:39:32Z         @nuzulultazkiya627
# ...                    ...                        ...
# 8874  2024-07-10T14:47:38Z           @jentrimissa3186
# 8875  2024-07-10T14:47:40Z               @itsskin5062
# 8876  2024-07-10T14:47:36Z  @dilatoebatulfakikhah7834
# 8877  2024-07-10T14:47:35Z          @keirashabira3891
# 8878  2024-07-10T14:47:34Z                  @Riyuniar
#
#                                             textDisplay  likeCount
# 0     Yaa Allah semoga anak2ku bisa seperti mereka 🤲...          0
# 1     Barakallahu fii Ilmi anak² cerdas. Semoga kece...          0
# 2                                                  🔥🔥🔥🔥          0
# ...

# %%
df.to_csv('PodcastDensuCOC.csv', index=False)
